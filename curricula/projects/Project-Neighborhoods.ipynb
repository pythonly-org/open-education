# %% [markdown]
# <h1><span data-sheets-root="1">🚀 </span>Identify Ideal neighborhoods for solar panels project</h1>
# <p>You're helping a local community organization decide where to offer free solar panel installations. <br>There&rsquo;s a limited budget, so they want to prioritize neighborhoods that would benefit the most.</p>
# <p>Your task: Identify neighborhoods that are ideal candidates for solar panels, based on how much sunlight they get, how much electricity they use, and their average income.</p>

# %% [markdown]
# <h2>Step 1: What Makes a <strong>Neighborhood</strong> a Good Fit?</h2>
# <p>Brainstorm what makes a neighborhood a good candidate for solar panels.&nbsp;</p>
# <p><br>Think about sunlight exposure, need for energy savings, and affordability. Use the design editor to sketch a diagram showing <br>key factors that influence solar panel suitability.</p>
# <p></p>
# <p><img src="Project-Neighborhoods.images/7a2437a5eed0d4e949ea0494b70bd4fe70b0fc9e73c459d2d736b50bdf3c8b8c.svg" data-drawing="{&quot;elements&quot;:[{&quot;type&quot;:&quot;ellipse&quot;,&quot;version&quot;:250,&quot;versionNonce&quot;:1252980461,&quot;isDeleted&quot;:false,&quot;id&quot;:&quot;Ax4u8Zjt-GnZPu6rTpBXQ&quot;,&quot;fillStyle&quot;:&quot;solid&quot;,&quot;strokeWidth&quot;:2,&quot;strokeStyle&quot;:&quot;solid&quot;,&quot;roughness&quot;:1,&quot;opacity&quot;:70,&quot;angle&quot;:0,&quot;x&quot;:285.65101722120437,&quot;y&quot;:178.0703125,&quot;strokeColor&quot;:&quot;#1e1e1e&quot;,&quot;backgroundColor&quot;:&quot;#ffec99&quot;,&quot;width&quot;:164.85289256917292,&quot;height&quot;:164.85289256917292,&quot;seed&quot;:298627411,&quot;groupIds&quot;:[],&quot;frameId&quot;:null,&quot;roundness&quot;:{&quot;type&quot;:2},&quot;boundElements&quot;:[{&quot;type&quot;:&quot;text&quot;,&quot;id&quot;:&quot;4ieTCf5eG6kPh9QYJObuo&quot;}],&quot;updated&quot;:1746703746000,&quot;link&quot;:null,&quot;locked&quot;:false},{&quot;type&quot;:&quot;text&quot;,&quot;version&quot;:165,&quot;versionNonce&quot;:2103828397,&quot;isDeleted&quot;:false,&quot;id&quot;:&quot;4ieTCf5eG6kPh9QYJObuo&quot;,&quot;fillStyle&quot;:&quot;solid&quot;,&quot;strokeWidth&quot;:2,&quot;strokeStyle&quot;:&quot;solid&quot;,&quot;roughness&quot;:1,&quot;opacity&quot;:70,&quot;angle&quot;:0,&quot;x&quot;:321.8990374967612,&quot;y&quot;:244.97437799377246,&quot;strokeColor&quot;:&quot;#1e1e1e&quot;,&quot;backgroundColor&quot;:&quot;#ffc9c9&quot;,&quot;width&quot;:92.78825378417969,&quot;height&quot;:31.4761633477484,&quot;seed&quot;:1253348979,&quot;groupIds&quot;:[],&quot;frameId&quot;:null,&quot;roundness&quot;:null,&quot;boundElements&quot;:[],&quot;updated&
quot;,&quot;currentItemStrokeWidth&quot;:2,&quot;currentItemStrokeStyle&quot;:&quot;solid&quot;,&quot;currentItemRoughness&quot;:1,&quot;currentItemOpacity&quot;:70,&quot;currentItemFontFamily&quot;:1,&quot;currentItemFontSize&quot;:28,&quot;currentItemTextAlign&quot;:&quot;left&quot;,&quot;currentItemStartArrowhead&quot;:null,&quot;currentItemEndArrowhead&quot;:&quot;arrow&quot;,&quot;exportWithDarkMode&quot;:false,&quot;exportBackground&quot;:true,&quot;gridSize&quot;:null,&quot;zoom&quot;:{&quot;value&quot;:1},&quot;scrollX&quot;:0,&quot;scrollY&quot;:0,&quot;selectedElementIds&quot;:{&quot;Ax4u8Zjt-GnZPu6rTpBXQ&quot;:true,&quot;o38zatWuIxk1at3as8ykM&quot;:true,&quot;UUPWPLBBbM5o3fejBIoBx&quot;:true},&quot;selectedGroupIds&quot;:{},&quot;editingElement&quot;:null,&quot;editingGroupId&quot;:null,&quot;name&quot;:&quot;Untitled-2025-05-08-1035&quot;}}" width="318.45445152879563" height="291.3203125" style="display: block; margin-left: auto; margin-right: auto;"></p>

# %%
from pyy.dataset import Dataset
from pyy.table_view import TableView

# VISIBLE_CODE_START
#✏️ First, let's pick the neighborhoods dataset and view it
Dataset(file_name='neighborhoods.csv', target=["match"],block_id='5Q8zKMN#0oT}PC$[w0-L')
TableView(max_rows=20, max_cols=10, title='(auto)', has_header=True, has_border=True, transpose=False,block_id='GMu.BU*Xd/txg39J|3X,')

#✏️ Running this will show the table structure and some data:
# VISIBLE_CODE_END
# Out:
# <h3 class='py-table-view-h3'>Neighborhoods Dataset</h3>
# ...

# %%
from pyy.dataset import Dataset
from pyy.plot import PairPlot

# VISIBLE_CODE_START
#✏️ Now, let's investigate the table features and target: We will use PairPlot for that -
Dataset(file_name='neighborhoods.csv', target=["match"],block_id='5Q8zKMN#0oT}PC$[w0-L')
PairPlot(columns=[], title='(auto)', cmap='tab10',block_id='RS91(FA:K=/IdqY}wd:F')

#✏️ This will show inter-dependencies among the numeric features (cells i!=j), as well as feature histogram (cells i=j) The dots colors show the target classes - True and False
# VISIBLE_CODE_END
# Out:
# 0
# [svg extracted to Project-Neighborhoods.images/f2f58e25028f467373c9a78c0044b5875c4307e490dd2f578367586068dd1813.svg]

# %% [markdown]
# <h2>Graph Output Explanation</h2>
# <p data-start="30" data-end="102">The graph illustrates how the target variable relates to each feature.</p>
# <p data-start="104" data-end="371">For instance, observing the third column/row reveals a strong relationship between <em data-start="187" data-end="203">average income</em> and <em data-start="208" data-end="229">solar project match</em>: orange dots appear more frequently in the lower income range, indicating that <strong>lower income levels are associated with a higher match rate</strong>.</p>
# <p data-start="373" data-end="485">One possible explanation is that households with lower income may be more motivated to reduce energy expenses.</p>
# <p data-start="487" data-end="564" data-is-last-node="" data-is-only-node="">Can you identify any other clear dependency between the target and a feature?</p>

# %% [markdown]
# <h2>Prediction: Building A Model</h2>
# <p data-start="34" data-end="181">To predict the <em data-start="49" data-end="56">match</em>, we&rsquo;ll create a simple model that captures the relationships observed earlier and allows us to make predictions on new data.</p>
# <p data-start="183" data-end="203"><strong data-start="183" data-end="203">Model structure:</strong></p>
# <ul data-start="205" data-end="390">
# <li data-start="205" data-end="285">
# <p data-start="207" data-end="285"><strong data-start="207" data-end="235">Encoder &ndash; OneHotEncoder:</strong> used to encode the categorical column <em data-start="274" data-end="282">"name"</em>.</p>
# </li>
# <li data-start="286" data-end="390">
# <p data-start="288" data-end="390"><strong data-start="288" data-end="324">Classifier &ndash; MaxEntropy:</strong> chosen as an example classifier (others could be used as well).</p>
# </li>
# </ul>
# <p data-start="392" data-end="562" data-is-last-node="" data-is-only-node="">These components will be wrapped together inside a <strong data-start="443" data-end="452">Model</strong>, ensuring that the same preprocessing and prediction steps can be consistently applied to any new input data.</p>

# %%
from pyy.encoder import Encoder
from pyy.classifier import Classifier
from pyy.model import Model
from pyy.dataset import Dataset

# VISIBLE_CODE_START
my_model=Model(
    Encoder(name='OneHotEncoder', columns=["name"],block_id='(kt[Ql;;?Z*8VDape?m4'),
    Classifier(name='MaxEntropy',block_id='@o:uCMJ~AG-d:C(30`*,')
,block_id='tM`j80YAYsXO%pc#cXb[')

Dataset(file_name='neighborhoods.csv', target=["match"],block_id='5z)yY[LvPSHR.d}=z(Z4')
my_model.fit(data=None)
print(my_model.get_score())
# VISIBLE_CODE_END
# Out:
# 0.93

# %% [markdown]
# <h2>Predict</h2>
# <article class="text-token-text-primary w-full focus:outline-none [--shadow-height:45px] has-data-writing-block:pointer-events-none has-data-writing-block:-mt-(--shadow-height) has-data-writing-block:pt-(--shadow-height) [&amp;:has([data-writing-block])&gt;*]:pointer-events-auto [content-visibility:auto] supports-[content-visibility:auto]:[contain-intrinsic-size:auto_100lvh] scroll-mt-[calc(var(--header-height)+min(200px,max(70px,20svh)))]" dir="auto" data-turn-id="2b725d2e-faf5-4ed2-b9c2-dca8f785e74a" data-testid="conversation-turn-20" data-scroll-anchor="true" data-turn="assistant" tabindex="-1">
# <div class="text-base my-auto mx-auto pb-10 [--thread-content-margin:--spacing(4)] thread-sm:[--thread-content-margin:--spacing(6)] thread-lg:[--thread-content-margin:--spacing(16)] px-(--thread-content-margin)">
# <div class="[--thread-content-max-width:40rem] thread-lg:[--thread-content-max-width:48rem] mx-auto max-w-(--thread-content-max-width) flex-1 group/turn-messages focus-visible:outline-hidden relative flex w-full min-w-0 flex-col agent-turn" tabindex="-1">
# <div class="flex max-w-full flex-col grow">
# <div data-message-author-role="assistant" data-message-id="df1105fe-ae38-401a-98fb-3c6550aaa209" dir="auto" class="min-h-8 text-message relative flex w-full flex-col items-end gap-2 text-start break-words whitespace-normal [.text-message+&amp;]:mt-1" data-message-model-slug="gpt-5">
# <div class="flex w-full flex-col gap-1 empty:hidden first:pt-[1px]">
# <div class="markdown prose dark:prose-invert w-full break-words dark markdown-new-styling">
# <p data-start="13" data-end="120">Now we&rsquo;re ready to provide the model with new data and see how it predicts the <em data-start="92" data-end="99">match</em> for a solar project.</p>
# <p data-start="122" data-end="135">To do this:</p>
# <ol data-start="136" data-end="328" data-is-last-node="" data-is-only-node="">
# <li data-start="136" data-end="195">
# <p data-start="139" data-end="195">Copy the block where we called <code data-start="170" data-end="192">my_model.get_score()</code>.</p>
# </li>
# <li data-start="196" data-end="229">
# <p data-start="199" data-end="229">Paste it into the next cell.</p>
# </li>
# <li data-start="230" data-end="328" data-is-last-node="">
# <p data-start="233" data-end="328" data-is-last-node="">Replace the method call <code data-start="257" data-end="270">get_score()</code> with <code data-start="276" data-end="287">predict()</code> to generate predictions on the new data.</p>
# </li>
# </ol>
# </div>
# </div>
# </div>
# </div>
# <div class="mt-3 w-full empty:hidden"></div>
# </div>
# </div>
# </article>

# %%
from pyy.custom_data import CustomData

# VISIBLE_CODE_START
CustomData(data=[
    {
        "name": "Sunfield",
        "sunlight_hours": 8.2,
        "avg_energy_use": 430.0,
        "avg_income": 20000.0
    },
    {
        "name": "Greencross",
        "sunlight_hours": 5.1,
        "avg_energy_use": 350.0,
        "avg_income": 30000.0
    },
    {
        "name": "Rivergrove",
        "sunlight_hours": 6.0,
        "avg_energy_use": 320.0,
        "avg_income": 67000.0
    }
], target=None,block_id=';k2p3ytQdCSZo0%p1Z4n')
print(my_model.predict(data=None))
# VISIBLE_CODE_END
# Out:
# [ True False False]

# %%
from pyy.custom_data import CustomData

# VISIBLE_CODE_START
CustomData(data=[
    {
        "name": "Sunfield",
        "sunlight_hours": 8.2,
        "avg_energy_use": 430.0,
        "avg_income": 20000.0
    },
    {
        "name": "Greencross",
        "sunlight_hours": 5.1,
        "avg_energy_use": 350.0,
        "avg_income": 30000.0
    },
    {
        "name": "Rivergrove",
        "sunlight_hours": 6.0,
        "avg_energy_use": 320.0,
        "avg_income": 67000.0
    }
], target=None,block_id=';k2p3ytQdCSZo0%p1Z4n')
print(my_model.predict(data=None))
# VISIBLE_CODE_END
# Out:
# [ True False False]

# %% [markdown]
# <h2>Results</h2>
# <p>Excellent! we got results that match our expectation:</p>
# <ul>
# <li>The first neighborhood with long sunlight exposure and low average income was predicted as match='True'</li>
# <li>The other two where predicted as match='False'</li>
# </ul>
# <p></p>
# <p><strong>Excercise</strong>: The model score can be improved if we add another pre-processing brick - can you guess which one?&nbsp;</p>
# <p>You're welcome to try it yourself!&nbsp;</p>
# <p></p>
