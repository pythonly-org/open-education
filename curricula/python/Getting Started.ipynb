# %%
# VISIBLE_CODE_START
#✏️ My First Program: Hello World!
#✏️ Toolbox - drag the 'print()' block from 'Common' category and drop it down here Then double-click & change the text from "Pythonly!" to "World!"
#✏️ 1
print('Hello World!')

#✏️ Run the code: click the play ▶️ button
#✏️ 2
#✏️ Output
#✏️ 3
# VISIBLE_CODE_END
# Out:
# Hello World!

# %%
# VISIBLE_CODE_START
#✏️ The Cell UI
#✏️ Click ▶ to run the cell code Click ◉ to toggle Code/Text cell type Click 🖋️ to open the graphic design editor
#✏️ Click <> to view the python code Click 🐞 to open the debugger
#✏️ The hover menu let you add, move down/up,  copy and delete a cell
#✏️ The toolbox - where you drag new blocks from It has 3 sections:   - All: a bucket of all Pythonly blocks   - Data Science: blocks used in data science tasks   - Python: pure Python language blocks
# VISIBLE_CODE_END

# %%
# VISIBLE_CODE_START
import math


#✏️ Explore more blocks
#✏️ Let's try some more blocks: From Math drag the sqrt (Square Root) block and drop here:
math.sqrt(9)

#✏️ Now change the value to 121  Then drag a 'print' block  Finally drag the sqrt block into the print input, instead of "Hello Pythonly!":
print('Hello Pythonly!')

print(math.sqrt(121))

#✏️ Run the code!
#✏️ You can also drag from List any list and print it:
print(["peach", "banana", "kiwi"])

#✏️ If you want to repeat a command, e.g. repeat the last print instruction 3 times you can simply drag the 'for' block from Loop:
for i in range(10):
  pass

#✏️ Then change the range to 3, and copy-paste the last print block into the 'for' body:
for i in range(3):
  print(["peach", "banana", "kiwi"])
# VISIBLE_CODE_END
# Out:
# Hello Pythonly!
# 11.0
# ['peach', 'banana', 'kiwi']
# ['peach', 'banana', 'kiwi']
# ['peach', 'banana', 'kiwi']
# ['peach', 'banana', 'kiwi']
