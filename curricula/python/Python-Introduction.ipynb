# %% [markdown]
# <h2><span data-sheets-root="1">🪄 Introduction to Python</span></h2>
# <p data-start="177" data-end="271">This guide will walk you through the basic steps of getting started with Python programming.</p>
# <p data-start="273" data-end="295">You&rsquo;ll learn how to:</p>
# <ul data-start="296" data-end="577">
# <li data-start="296" data-end="338">
# <p data-start="298" data-end="338">Write and run your first lines of code</p>
# </li>
# <li data-start="339" data-end="391">
# <p data-start="341" data-end="391">Display information using the <code data-start="371" data-end="380">print()</code> function</p>
# </li>
# <li data-start="392" data-end="439">
# <p data-start="394" data-end="439">Work with simple data like numbers and text</p>
# </li>
# <li data-start="440" data-end="488">
# <p data-start="442" data-end="488">Repeat actions using <code data-start="463" data-end="468">for</code>&nbsp; loop</p>
# </li>
# <li data-start="489" data-end="577">
# <p data-start="491" data-end="577">Interact with basic on-screen elements through simple input and output (UI) examples</p>
# </li>
# </ul>
# <p data-start="579" data-end="704" data-is-last-node="" data-is-only-node="">By the end, you&rsquo;ll understand how Python executes code step by step and how to build small, interactive programs of your own.</p>

# %%
# VISIBLE_CODE_START
#✏️ My first python program
#✏️ Toolbox - drag instructions from the menu and drop into the working area
# VISIBLE_CODE_END

# %%
# VISIBLE_CODE_START
#✏️ Dragging first command
#✏️ First make sure Python is selected in the leftmost sidebar (vertical tabs)
#✏️ Select "Text", then drag the "print('Hello Pythonly!')" and drop here
print('Hello Pythonly!')

#✏️ (You can also find this command in the category 'Common', as it's quite a commonly used instruction)
# VISIBLE_CODE_END
# Out:
# Hello Pythonly!

# %%
# VISIBLE_CODE_START
#✏️ Running the program
#✏️ Click the play button - Run the code
print('Hello Pythonly!')

#✏️ Output
# VISIBLE_CODE_END
# Out:
# Hello Pythonly!

# %%
# VISIBLE_CODE_START
#✏️ Change the text inside the print instruction: set there your name
print('Hello <your name>!')

#✏️ Then run again and watch the output
# VISIBLE_CODE_END
# Out:
# Hello <your name>!

# %%
# VISIBLE_CODE_START
#✏️ Next, pick from Python => Loops => For (the first block) Attach it to your print block, then change the loop count to 3
for k in range(3):
  print('Hello <your name>!')

#✏️ Then run again and watch the output
# VISIBLE_CODE_END
# Out:
# Hello <your name>!
# Hello <your name>!
# Hello <your name>!

# %%
# VISIBLE_CODE_START
#✏️ Actually, we can even do something smarter: print the  index of the current iteration in the loop:
for j in range(3):
  print(j)

#✏️ Run the cell code and watch the 3 indices
# VISIBLE_CODE_END
# Out:
# 0
# 1
# 2

# %%
# VISIBLE_CODE_START
for j in range(3):
  print(j)

#✏️ You can click the code symbol '<>' (toolbar upper-right) to watch the python generated code!
# VISIBLE_CODE_END
# Out:
# 0
# 1
# 2

# %%
# VISIBLE_CODE_START
for i in range(3):
  print(i)

#✏️ Clicking the debugger button 🪲 will open the debugger sidebar and let you run the code step-by-step, with  the variable values displayed
# VISIBLE_CODE_END
# Out:
# 0
# 1
# 2
